# %%
TECHNIQUE_OPTIONS = [
    "Scanning electron microscopy (SEM)",
    "Transmission electron microscopy (TEM)",
    "Atomic force microscopy (AFM)",
    "Reflected light microscopy"
]

CATEGORY_OPTIONS = [
    "Metal or alloy",
    "Ceramic",
    "Polymer",
    "Composite",
    "Fracture"
]

# %%
def technique_mcq_prompt():
    return (
        "Look carefully at the microscopy image and identify the imaging technique.\n\n"
        "A. Scanning electron microscopy (SEM)\n"
        "B. Transmission electron microscopy (TEM)\n"
        "C. Atomic force microscopy (AFM)\n"
        "D. Reflected light microscopy\n\n"
        "Answer with only one letter."
    )

def category_mcq_prompt():
    return (
        "Which material category best describes the image?\n\n"
        "A. Metal or alloy\n"
        "B. Ceramic\n"
        "C. Polymer\n"
        "D. Composite\n"
        "E. Fracture\n\n"
        "Answer with only one letter."
    )

# %%
def parse_answer(text, valid):
    text = text.upper()
    for v in valid:
        if v in text:
            return v
    return None

def gt_to_letter(gt, options):
    try:
        return chr(ord("A") + options.index(gt))
    except:
        return None

# %%
import torch
from transformers import LlavaForConditionalGeneration, LlavaProcessor

def load_model(path, device):
    model = LlavaForConditionalGeneration.from_pretrained(
        path,
        torch_dtype=torch.float16
    ).to(device)

    processor = LlavaProcessor.from_pretrained(path)

    model.eval()
    return model, processor

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
MODEL_PATH = "/mnt/d/Subham/model/llava-v1.6-mistral-7b-hf"

model, processor = load_model(MODEL_PATH, device)
# Out:
# `torch_dtype` is deprecated! Use `dtype` instead!
# You are using a model of type llava_next to instantiate a model of type llava. This is not supported for all configurations of models and can yield errors.
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.

# %%
def parse_answer(text, valid_letters):
    text = text.upper()
    for v in valid_letters:
        if v in text:
            return v
    return None

def gt_to_letter(gt_value, options):
    try:
        return chr(ord("A") + options.index(gt_value))
    except:
        return None

# %%
def run_vlm(model, processor, image, prompt, device):

    messages = [
        {
            "role": "user",
            "content": [
                {"type": "image"},
                {"type": "text", "text": prompt}
            ]
        }
    ]

    # Apply official LLaVA chat template
    text = processor.apply_chat_template(
        messages,
        tokenize=False,
        add_generation_prompt=True
    )

    inputs = processor(
        images=image,
        text=text,
        return_tensors="pt"
    )

    # LLaVA v1.6 compatibility fixes
    inputs.pop("image_sizes", None)

    if inputs["pixel_values"].ndim == 5:
        inputs["pixel_values"] = inputs["pixel_values"][:, 0]

    inputs = inputs.to(device)

    with torch.no_grad():
        output = model.generate(
            **inputs,
            max_new_tokens=5,
            do_sample=False,
            pad_token_id=model.config.eos_token_id
        )

    return processor.decode(output[0], skip_special_tokens=True)

# %%
import pandas as pd
from PIL import Image
from tqdm import tqdm
import time

CSV_PATH = "qa.csv"
df = pd.read_csv(CSV_PATH)

start_time = time.time()
y_true_tech = []
y_pred_tech = []

y_true_cat = []
y_pred_cat = []

for _, row in tqdm(df.iterrows(), total=len(df)):

    # --- Safe image loading ---
    try:
        image = Image.open(row["image_local_path"]).convert("RGB")
    except Exception:
        continue

    # -------- Technique MCQ --------
    tech_out = run_vlm(
        model,
        processor,
        image,
        technique_mcq_prompt(),
        device
    )

    tech_pred = parse_answer(tech_out, ["A", "B", "C", "D"])
    tech_gt   = gt_to_letter(row["technique"], TECHNIQUE_OPTIONS)

    if tech_pred is not None and tech_gt is not None:
        y_pred_tech.append(tech_pred)
        y_true_tech.append(tech_gt)

    # -------- Category MCQ --------
    cat_out = run_vlm(
        model,
        processor,
        image,
        category_mcq_prompt(),
        device
    )

    cat_pred = parse_answer(cat_out, ["A", "B", "C", "D", "E"])
    cat_gt   = gt_to_letter(row["categories"], CATEGORY_OPTIONS)

    if cat_pred is not None and cat_gt is not None:
        y_pred_cat.append(cat_pred)
        y_true_cat.append(cat_gt)
# Calculate total time
total_time = time.time() - start_time
print(f"\nTotal processing time: {total_time:.2f} seconds")
print(f"Average time per image: {total_time/len(df):.2f} seconds")
# Out:
#   0%|                                                                                | 0/51 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   2%|█▍                                                                      | 1/51 [00:00<00:39,  1.25it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   4%|██▊                                                                     | 2/51 [00:01<00:35,  1.36it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   6%|████▏                                                                   | 3/51 [00:02<00:33,  1.42it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   8%|█████▋                                                                  | 4/51 [00:02<00:32,  1.44it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  10%|███████                                                                 | 5/51 [00:03<00:31,  1.46it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  12%|████████▍                                                               | 6/51 [00:04<00:30,  1.46it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  14%|█████████▉                                                              | 7/51 [00:04<00:30,  1.42it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  16%|███████████▎                                                            | 8/51 [00:05<00:29,  1.43it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  18%|████████████▋                                                           | 9/51 [00:06<00:29,  1.45it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  20%|█████████████▉                                                         | 10/51 [00:07<00:28,  1.43it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  22%|███████████████▎                                                       | 11/51 [00:08<00:36,  1.10it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  24%|████████████████▋                                                      | 12/51 [00:09<00:32,  1.18it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  25%|██████████████████                                                     | 13/51 [00:09<00:30,  1.24it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  27%|███████████████████▍                                                   | 14/51 [00:10<00:28,  1.29it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  29%|████████████████████▉                                                  | 15/51 [00:11<00:27,  1.32it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  31%|██████████████████████▎                                                | 16/51 [00:11<00:26,  1.34it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  33%|███████████████████████▋                                               | 17/51 [00:12<00:24,  1.37it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  35%|█████████████████████████                                              | 18/51 [00:13<00:23,  1.41it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  37%|██████████████████████████▍                                            | 19/51 [00:13<00:22,  1.43it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  39%|███████████████████████████▊                                           | 20/51 [00:14<00:21,  1.44it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  41%|█████████████████████████████▏                                         | 21/51 [00:15<00:21,  1.42it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  43%|██████████████████████████████▋                                        | 22/51 [00:16<00:20,  1.39it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  45%|████████████████████████████████                                       | 23/51 [00:16<00:20,  1.38it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  47%|█████████████████████████████████▍                                     | 24/51 [00:17<00:19,  1.38it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  49%|██████████████████████████████████▊                                    | 25/51 [00:18<00:19,  1.37it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  51%|████████████████████████████████████▏                                  | 26/51 [00:19<00:18,  1.37it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  53%|█████████████████████████████████████▌                                 | 27/51 [00:19<00:17,  1.36it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  55%|██████████████████████████████████████▉                                | 28/51 [00:20<00:16,  1.36it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  57%|████████████████████████████████████████▎                              | 29/51 [00:21<00:16,  1.36it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  59%|█████████████████████████████████████████▊                             | 30/51 [00:22<00:15,  1.37it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  61%|███████████████████████████████████████████▏                           | 31/51 [00:22<00:14,  1.34it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  63%|████████████████████████████████████████████▌                          | 32/51 [00:23<00:13,  1.39it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  65%|█████████████████████████████████████████████▉                         | 33/51 [00:24<00:12,  1.43it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  67%|███████████████████████████████████████████████▎                       | 34/51 [00:24<00:11,  1.43it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  69%|████████████████████████████████████████████████▋                      | 35/51 [00:25<00:11,  1.44it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  71%|██████████████████████████████████████████████████                     | 36/51 [00:26<00:10,  1.47it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  73%|███████████████████████████████████████████████████▌                   | 37/51 [00:26<00:09,  1.49it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  75%|████████████████████████████████████████████████████▉                  | 38/51 [00:27<00:08,  1.51it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  76%|██████████████████████████████████████████████████████▎                | 39/51 [00:28<00:07,  1.51it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  78%|███████████████████████████████████████████████████████▋               | 40/51 [00:28<00:07,  1.52it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  80%|█████████████████████████████████████████████████████████              | 41/51 [00:29<00:06,  1.50it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  82%|██████████████████████████████████████████████████████████▍            | 42/51 [00:30<00:06,  1.47it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  84%|███████████████████████████████████████████████████████████▊           | 43/51 [00:30<00:05,  1.45it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  86%|█████████████████████████████████████████████████████████████▎         | 44/51 [00:31<00:04,  1.45it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  88%|██████████████████████████████████████████████████████████████▋        | 45/51 [00:32<00:04,  1.45it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  90%|████████████████████████████████████████████████████████████████       | 46/51 [00:32<00:03,  1.45it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  92%|█████████████████████████████████████████████████████████████████▍     | 47/51 [00:33<00:02,  1.44it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  94%|██████████████████████████████████████████████████████████████████▊    | 48/51 [00:34<00:02,  1.44it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  96%|████████████████████████████████████████████████████████████████████▏  | 49/51 [00:35<00:01,  1.44it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  98%|█████████████████████████████████████████████████████████████████████▌ | 50/51 [00:35<00:00,  1.43it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# 100%|███████████████████████████████████████████████████████████████████████| 51/51 [00:36<00:00,  1.40it/s]
# Total processing time: 36.43 seconds
# Average time per image: 0.71 seconds

# %%
from sklearn.metrics import (
    accuracy_score,
    balanced_accuracy_score,
    precision_recall_fscore_support,
    confusion_matrix
)

def print_metrics(y_true, y_pred, name):
    acc = accuracy_score(y_true, y_pred)
    bal_acc = balanced_accuracy_score(y_true, y_pred)

    prec, rec, f1, _ = precision_recall_fscore_support(
        y_true, y_pred,
        average="macro",
        zero_division=0
    )

    print(f"\n=== {name} ===")
    print(f"Samples            : {len(y_true)}")
    print(f"Accuracy           : {acc:.3f}")
    print(f"Balanced Accuracy  : {bal_acc:.3f}")
    print(f"Macro Precision    : {prec:.3f}")
    print(f"Macro Recall       : {rec:.3f}")
    print(f"Macro F1-score     : {f1:.3f}")

# %%
print_metrics(y_true_tech, y_pred_tech, "Technique Classification")
print_metrics(y_true_cat,  y_pred_cat,  "Category Classification")
# Out:
# === Technique Classification ===
# Samples            : 46
# Accuracy           : 0.261
# Balanced Accuracy  : 0.250
# Macro Precision    : 0.065
# Macro Recall       : 0.250
# Macro F1-score     : 0.103
#
# === Category Classification ===
# Samples            : 45
# Accuracy           : 0.556
# Balanced Accuracy  : 0.250
# Macro Precision    : 0.139
# Macro Recall       : 0.250
# Macro F1-score     : 0.179
